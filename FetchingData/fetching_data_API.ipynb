# %%
import pandas as pd

# %%
import requests

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Y2FiOTQ2ZmRlYjBiMWJiMzlhZmI5YWYxZjFkM2M0MSIsIm5iZiI6MTczODg3NTc2Mi44NTYsInN1YiI6IjY3YTUyMzcyZjE5NmE3M2FlNzY2ZjhlYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.P4neJoJZppb5kocL9GhQ8isEZQZHQWi72LpbahIAflw"
}

# %%
df = pd.DataFrame()

all_pages = []

for i in range(1, 149):

  response = requests.get("https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i), headers=headers)

  temp_df = pd.DataFrame(response.json()['results'])[['id', 'original_title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
  all_pages.append(temp_df)

df = pd.concat(all_pages, ignore_index = True)

df
# Out:
#           id                original_title  \
# 0        278      The Shawshank Redemption
# 1        238                 The Godfather
# 2        240         The Godfather Part II
# 3        424              Schindler's List
# 4        389                  12 Angry Men
# ...      ...                           ...
# 2955  856289                    封神第一部：朝歌风云
# 2956  618355             Superman: Red Son
# 2957  617126  The Fantastic 4: First Steps
# 2958   11485        Take the Money and Run
# 2959  594530                     Lamp Life
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...
